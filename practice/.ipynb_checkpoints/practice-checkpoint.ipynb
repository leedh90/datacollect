# %%
import pandas as pd
import numpy as np

# %%
practice0 = pd.DataFrame({"이름": ["홍길동", "김길동"], "나이":[100, 200]})
practice0
# Out:
#     이름   나이
# 0  홍길동  100
# 1  김길동  200

# %%
practice = pd.DataFrame({"날짜":[], "운동":[], "양":[]})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 양]
# Index: []

# %%
# loc[행인덱스] => 행인덱스에 한 행을 추가해라
practice.loc[0] = ["19-3-1", "달리기", 1.] # loc row[0]번째 행 넣기
practice
# Out:
#        날짜   운동    양
# 0  19-3-1  달리기  1.0

# %%
practice.loc[1] = ["19-3-2", "걷기", 1.]
practice.loc[2] = ["19-3-2", "달리기", 1.]
practice.loc[3] = ["19-3-2", "계단오르기", 1.]
practice
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0

# %%
practice.loc[4] = ["19-3-3", "걷기", 1.5]
practice.loc[5] = ["19-3-3", "달리기", 1.]
practice
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0
# 4  19-3-3     걷기  1.5
# 5  19-3-3    달리기  1.0

# %%
practice.to_csv("../../Downloads/practice2.csv", encoding="utf-8") # 파일을 저장하기 위해서는 to_csv 사용해서 저장할 수 있다.
# 경로 지정을 잘 해줘야한다.

# %%
practice2 = pd.read_csv("../../Downloads/practice.csv", index_col=0, encoding="utf-8")
practice2
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0
# 4  19-3-3     걷기  1.5
# 5  19-3-3    달리기  1.0

# %%
practice2.loc[6] = ["19-3-4", "걷기", 1.5]
practice2.loc[7] = ["19-3-5", "달리기", 1.]
practice2.loc[8] = ["19-3-6", "걷기", 2.5]
practice2.loc[9] = ["19-3-6", "달리기", 0.5]
practice2
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0
# 4  19-3-3     걷기  1.5
# 5  19-3-3    달리기  1.0
# 6  19-3-4     걷기  1.5
# 7  19-3-5    달리기  1.0
# 8  19-3-6     걷기  2.5
# 9  19-3-6    달리기  0.5

# %%
practice2.pivot_table(index="운동") # avg 평균으로 구해준다.
# Out:
#            양
# 운동
# 걷기     1.625
# 계단오르기  1.000
# 달리기    0.900

# %%
practice2.pivot_table(index="운동", aggfunc=np.sum) # 합계를 구하기 위해서는 aggfunc기능과 numpy 기능을 사용
# Out:
#          양
# 운동
# 걷기     6.5
# 계단오르기  1.0
# 달리기    4.5

# %%
practice2.pivot_table(index="운동", aggfunc=[np.sum, len]) # 여러개를 묶을때는 리스트나 튜플로 묶어준다.
# Out:
#        sum len
#          양  날짜    양
# 운동
# 걷기     6.5   4  4.0
# 계단오르기  1.0   1  1.0
# 달리기    4.5   5  5.0

# %%
practice2.pivot_table(index="운동", aggfunc=[np.sum, np.average, len]) # len은 갯수이다. 예)걷기는 4개
# Out:
#        sum average len
#          양       양  날짜    양
# 운동
# 걷기     6.5   1.625   4  4.0
# 계단오르기  1.0   1.000   1  1.0
# 달리기    4.5   0.900   5  5.0

# %%
prac_pivot = practice2.pivot("날짜", "운동", "양")
#                           인덱스(행), 종류(열), 테이블 가운데 채워지는 값(양)
# 각각의 위치가 어디인지 확인 꼭 필요!
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  NaN    NaN  1.0
# 19-3-2  1.0    1.0  1.0
# 19-3-3  1.5    NaN  1.0
# 19-3-4  1.5    NaN  NaN
# 19-3-5  NaN    NaN  1.0
# 19-3-6  2.5    NaN  0.5

# %%
# NaN: 행과 열에 적합한 값이 없다 -> 삭제, 수치로 변환.
# 수치변환: 평균, 0, 내가 원하는 특정한 기본값으로 변환(상황에 따라서 맞는 방법을 사용한다.)

# %%
prac_pivot.fillna(0, inplace=True) # fillna -> NaN 이라는 값을 대체하는 함수!
# fillna는 비파괴함수라서 파괴함수로 옵션을 줘야한다. inplace 옵션이 비파괴함수 -> 파괴함수로 변경하는 옵션
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  0.0    0.0  1.0
# 19-3-2  1.0    1.0  1.0
# 19-3-3  1.5    0.0  1.0
# 19-3-4  1.5    0.0  0.0
# 19-3-5  0.0    0.0  1.0
# 19-3-6  2.5    0.0  0.5

# %%
not_excercise = pd.read_excel("../../Downloads/reason_not_exercise.xls") # 경로 지정 중요!
not_excercise
# Out:
#       기간    대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  \
# 0   2017    서울시           서울시               49.7              8.1
# 1   2017     성별            남자               55.2              7.9
# 2   2017     성별            여자               45.0              8.3
# 3   2017    연령별           10대               55.7              6.1
# 4   2017    연령별           20대               54.8              6.9
# 5   2017    연령별           30대               58.1              5.5
# 6   2017    연령별           40대               57.7              6.8
# 7   2017    연령별           50대               50.1              9.2
# 8   2017    연령별        60대 이상               27.5             12.8
# 9   2017    학력별         중졸 이하               26.1             13.7
# 10  2017    학력별         고졸 이하               46.3              8.5
# 11  2017    학력별         대졸 이하               57.4              6.6
# 12  2017    학력별        대학원 이상               65.3              3.8
# 13  2017    소득별      100만원 미만               22.7             10.3
# 14  2017    소득별  100-200만원 미만               34.3             11.5
# 15  2017    소득별  200-300만원 미만               48.8             12.3
# 16  2017    소득별  300-400만원 미만               54.9              7.1
# 17  2017    소득별  400-500만원 미만               56.1                5
# 18  2017    소득별      500만원 이상               52.3              7.1
# 19  2017  혼인상태별            기혼               50.7              7.8
# 20  2017  혼인상태별            미혼               54.3              7.1
# 21  2017  혼인상태별         이혼/별거               47.4              8.3
# 22  2017  혼인상태별            사별               25.2             14.9
# 23  2017  지역대분류           도심권               50.5              6.9
# 24  2017  지역대분류           동북권               47.4              7.9
# 25  2017  지역대분류           서북권               49.4             13.9
# 26  2017  지역대분류           서남권               50.7              6.7
# 27  2017  지역대분류           동남권               52.2              6.9
# 28  2017    종로구           종로구               41.4             18.2
# 29  2017     중구            중구               51.0              1.2
# 30  2017    용산구           용산구               55.9              3.8
# 31  2017    성동구           성동구               50.5                5
# 32  2017    광진구           광진구               49.1              8.5
# 33  2017   동대문구          동대문구               47.2              1.7
# 34  2017    중랑구           중랑구               47.9              3.9
# 35  2017    성북구           성북구               43.4             16.1
# 36  2017    강북구           강북구               48.4              7.2
# 37  2017    도봉구           도봉구               52.0              8.6
# 38  2017    노원구           노원구               44.6              7.8
# 39  2017    은평구           은평구               44.8             17.7
# 40  2017   서대문구          서대문구               58.6              5.8
# 41  2017    마포구           마포구               47.7             15.6
# 42  2017    양천구           양천구               55.2             11.5
# 43  2017    강서구           강서구               59.0              8.3
# 44  2017    구로구           구로구               42.9              6.1
# 45  2017    금천구           금천구               42.4              7.8
# 46  2017   영등포구          영등포구               53.8              3.4
# 47  2017    동작구           동작구               46.0                -
# 48  2017    관악구           관악구               50.7              7.1
# 49  2017    서초구           서초구               59.8              3.4
# 50  2017    강남구           강남구               59.1              5.5
# 51  2017    송파구           송파구               42.6              7.2
# 52  2017    강동구           강동구               53.1              9.6
#
#     운동을 할 만한 장소가 없어서  운동을 싫어해서    기타
# 0                5.8      34.7   1.7
# 1                5.5      29.8   1.6
# 2                6.0      38.8   1.8
# 3                5.6      32.2   0.3
# 4                5.2      32.9   0.1
# 5                4.6      31.6   0.2
# 6                5.2      29.4     1
# 7                7.2      32.2   1.4
# 8                6.9      46.8     6
# 9                6.6      46.2   7.4
# 10               6.9      36.5   1.7
# 11               4.9      30.7   0.4
# 12               0.6      29.6   0.6
# 13               3.6      50.7  12.7
# 14               7.1      41.5   5.6
# 15               6.8      30.7   1.4
# 16               6.5      31.2   0.3
# 17               5.3      33.0   0.6
# 18               5.1      34.9   0.6
# 19               5.4      34.9   1.2
# 20               5.4      32.2     1
# 21               6.8      34.9   2.7
# 22               8.9      42.9     8
# 23               4.5      36.4   1.7
# 24               5.9      36.1   2.7
# 25               7.4      28.5   0.8
# 26               5.7      35.0   1.9
# 27               4.9      35.4   0.6
# 28               7.8      32.4   0.2
# 29               1.9      40.5   5.5
# 30               4.3      36.0     -
# 31               6.8      37.8     -
# 32               5.6      32.5   4.4
# 33               3.4      43.6   4.2
# 34               5.7      42.0   0.4
# 35               6.1      33.4     1
# 36               6.7      37.7     -
# 37               5.1      32.0   2.3
# 38               7.2      32.5   7.9
# 39               7.1      29.7   0.8
# 40               7.9      27.3   0.5
# 41               7.5      28.0   1.2
# 42              10.6      22.3   0.3
# 43               4.0      27.1   1.6
# 44               7.3      43.3   0.4
# 45               3.2      46.1   0.5
# 46               4.0      34.8     4
# 47               1.1      47.0   5.9
# 48               6.9      33.6   1.7
# 49               3.2      32.0   1.5
# 50               2.6      31.5   1.3
# 51               5.8      44.3   0.1
# 52               6.8      30.4   0.1

# %%
not_excercise.drop(columns="기간", inplace=True) # drop도 비파괴함수이기 때문에 inplace 사용
not_excercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0     서울시           서울시               49.7              8.1               5.8
# 1      성별            남자               55.2              7.9               5.5
# 2      성별            여자               45.0              8.3               6.0
# 3     연령별           10대               55.7              6.1               5.6
# 4     연령별           20대               54.8              6.9               5.2
# 5     연령별           30대               58.1              5.5               4.6
# 6     연령별           40대               57.7              6.8               5.2
# 7     연령별           50대               50.1              9.2               7.2
# 8     연령별        60대 이상               27.5             12.8               6.9
# 9     학력별         중졸 이하               26.1             13.7               6.6
# 10    학력별         고졸 이하               46.3              8.5               6.9
# 11    학력별         대졸 이하               57.4              6.6               4.9
# 12    학력별        대학원 이상               65.3              3.8               0.6
# 13    소득별      100만원 미만               22.7             10.3               3.6
# 14    소득별  100-200만원 미만               34.3             11.5               7.1
# 15    소득별  200-300만원 미만               48.8             12.3               6.8
# 16    소득별  300-400만원 미만               54.9              7.1               6.5
# 17    소득별  400-500만원 미만               56.1                5               5.3
# 18    소득별      500만원 이상               52.3              7.1               5.1
# 19  혼인상태별            기혼               50.7              7.8               5.4
# 20  혼인상태별            미혼               54.3              7.1               5.4
# 21  혼인상태별         이혼/별거               47.4              8.3               6.8
# 22  혼인상태별            사별               25.2             14.9               8.9
# 23  지역대분류           도심권               50.5              6.9               4.5
# 24  지역대분류           동북권               47.4              7.9               5.9
# 25  지역대분류           서북권               49.4             13.9               7.4
# 26  지역대분류           서남권               50.7              6.7               5.7
# 27  지역대분류           동남권               52.2              6.9               4.9
# 28    종로구           종로구               41.4             18.2               7.8
# 29     중구            중구               51.0              1.2               1.9
# 30    용산구           용산구               55.9              3.8               4.3
# 31    성동구           성동구               50.5                5               6.8
# 32    광진구           광진구               49.1              8.5               5.6
# 33   동대문구          동대문구               47.2              1.7               3.4
# 34    중랑구           중랑구               47.9              3.9               5.7
# 35    성북구           성북구               43.4             16.1               6.1
# 36    강북구           강북구               48.4              7.2               6.7
# 37    도봉구           도봉구               52.0              8.6               5.1
# 38    노원구           노원구               44.6              7.8               7.2
# 39    은평구           은평구               44.8             17.7               7.1
# 40   서대문구          서대문구               58.6              5.8               7.9
# 41    마포구           마포구               47.7             15.6               7.5
# 42    양천구           양천구               55.2             11.5              10.6
# 43    강서구           강서구               59.0              8.3               4.0
# 44    구로구           구로구               42.9              6.1               7.3
# 45    금천구           금천구               42.4              7.8               3.2
# 46   영등포구          영등포구               53.8              3.4               4.0
# 47    동작구           동작구               46.0                -               1.1
# 48    관악구           관악구               50.7              7.1               6.9
# 49    서초구           서초구               59.8              3.4               3.2
# 50    강남구           강남구               59.1              5.5               2.6
# 51    송파구           송파구               42.6              7.2               5.8
# 52    강동구           강동구               53.1              9.6               6.8
#
#     운동을 싫어해서    기타
# 0       34.7   1.7
# 1       29.8   1.6
# 2       38.8   1.8
# 3       32.2   0.3
# 4       32.9   0.1
# 5       31.6   0.2
# 6       29.4     1
# 7       32.2   1.4
# 8       46.8     6
# 9       46.2   7.4
# 10      36.5   1.7
# 11      30.7   0.4
# 12      29.6   0.6
# 13      50.7  12.7
# 14      41.5   5.6
# 15      30.7   1.4
# 16      31.2   0.3
# 17      33.0   0.6
# 18      34.9   0.6
# 19      34.9   1.2
# 20      32.2     1
# 21      34.9   2.7
# 22      42.9     8
# 23      36.4   1.7
# 24      36.1   2.7
# 25      28.5   0.8
# 26      35.0   1.9
# 27      35.4   0.6
# 28      32.4   0.2
# 29      40.5   5.5
# 30      36.0     -
# 31      37.8     -
# 32      32.5   4.4
# 33      43.6   4.2
# 34      42.0   0.4
# 35      33.4     1
# 36      37.7     -
# 37      32.0   2.3
# 38      32.5   7.9
# 39      29.7   0.8
# 40      27.3   0.5
# 41      28.0   1.2
# 42      22.3   0.3
# 43      27.1   1.6
# 44      43.3   0.4
# 45      46.1   0.5
# 46      34.8     4
# 47      47.0   5.9
# 48      33.6   1.7
# 49      32.0   1.5
# 50      31.5   1.3
# 51      44.3   0.1
# 52      30.4   0.1

# %%
not_excercise.drop(index=range(22, 53), inplace=True) # index 범위를 줘서 삭제해줄 수 있다.
not_excercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0     서울시           서울시               49.7              8.1               5.8
# 1      성별            남자               55.2              7.9               5.5
# 2      성별            여자               45.0              8.3               6.0
# 3     연령별           10대               55.7              6.1               5.6
# 4     연령별           20대               54.8              6.9               5.2
# 5     연령별           30대               58.1              5.5               4.6
# 6     연령별           40대               57.7              6.8               5.2
# 7     연령별           50대               50.1              9.2               7.2
# 8     연령별        60대 이상               27.5             12.8               6.9
# 9     학력별         중졸 이하               26.1             13.7               6.6
# 10    학력별         고졸 이하               46.3              8.5               6.9
# 11    학력별         대졸 이하               57.4              6.6               4.9
# 12    학력별        대학원 이상               65.3              3.8               0.6
# 13    소득별      100만원 미만               22.7             10.3               3.6
# 14    소득별  100-200만원 미만               34.3             11.5               7.1
# 15    소득별  200-300만원 미만               48.8             12.3               6.8
# 16    소득별  300-400만원 미만               54.9              7.1               6.5
# 17    소득별  400-500만원 미만               56.1                5               5.3
# 18    소득별      500만원 이상               52.3              7.1               5.1
# 19  혼인상태별            기혼               50.7              7.8               5.4
# 20  혼인상태별            미혼               54.3              7.1               5.4
# 21  혼인상태별         이혼/별거               47.4              8.3               6.8
#
#     운동을 싫어해서    기타
# 0       34.7   1.7
# 1       29.8   1.6
# 2       38.8   1.8
# 3       32.2   0.3
# 4       32.9   0.1
# 5       31.6   0.2
# 6       29.4     1
# 7       32.2   1.4
# 8       46.8     6
# 9       46.2   7.4
# 10      36.5   1.7
# 11      30.7   0.4
# 12      29.6   0.6
# 13      50.7  12.7
# 14      41.5   5.6
# 15      30.7   1.4
# 16      31.2   0.3
# 17      33.0   0.6
# 18      34.9   0.6
# 19      34.9   1.2
# 20      32.2     1
# 21      34.9   2.7

# %%
not_excercise.shape # shape 는 행렬의 크기를 볼 수 있는 함수
# Out:
# (22, 7)

# %%
not_excercise["대분류"] # 대분류에 있는 항목명만 쭉 출력!
# Out:
# 0       서울시
# 1        성별
# 2        성별
# 3       연령별
# 4       연령별
# 5       연령별
# 6       연령별
# 7       연령별
# 8       연령별
# 9       학력별
# 10      학력별
# 11      학력별
# 12      학력별
# 13      소득별
# 14      소득별
# 15      소득별
# 16      소득별
# 17      소득별
# 18      소득별
# 19    혼인상태별
# 20    혼인상태별
# 21    혼인상태별
# Name: 대분류, dtype: object

# %%
not_excercise["운동을 할 충분한 시간이 없어서"] # 컬럼명을 지정해서 해당 값을 다 출력도 가능
# Out:
# 0     49.7
# 1     55.2
# 2     45.0
# 3     55.7
# 4     54.8
# 5     58.1
# 6     57.7
# 7     50.1
# 8     27.5
# 9     26.1
# 10    46.3
# 11    57.4
# 12    65.3
# 13    22.7
# 14    34.3
# 15    48.8
# 16    54.9
# 17    56.1
# 18    52.3
# 19    50.7
# 20    54.3
# 21    47.4
# Name: 운동을 할 충분한 시간이 없어서, dtype: float64

# %%
not_excercise["대분류"] == "성별" # 대분류가 성별이랑 같으면 True, 다르면 False
# 브로드캐스팅 내가 준 조건을 모든 값과 비교해서 출력하는 방식
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: 대분류, dtype: bool

# %%
# not_excercise[] # [] 는 조건을 넣기 위한 역할

# %%
not_excercise[not_excercise["대분류"] == "성별"] # 조건을 안으로 주면 해당 조건값만 추출가능
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  성별  남자               55.2              7.9               5.5      29.8  1.6
# 2  성별  여자               45.0              8.3               6.0      38.8  1.8

# %%
not_ex_sex = not_excercise[not_excercise["대분류"] == "성별"].copy()
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  성별  남자               55.2              7.9               5.5      29.8  1.6
# 2  성별  여자               45.0              8.3               6.0      38.8  1.8

# %%
not_ex_sex.drop(columns="대분류", inplace=True) # 필요없는 대분류 삭제해서 필요한 값만 보기
not_ex_sex
# Out:
#    분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  남자               55.2              7.9               5.5      29.8  1.6
# 2  여자               45.0              8.3               6.0      38.8  1.8

# %%
not_ex_sex.set_index("분류", inplace=True) # 기본인덱스를 분류로 변경해준다.
not_ex_sex
# Out:
#     운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 분류
# 남자               55.2              7.9               5.5      29.8  1.6
# 여자               45.0              8.3               6.0      38.8  1.8

# %%
import matplotlib.pyplot as plt # 시각화를 위한 import -> matplotlip.pyplot 를 임포트 해야한다.

# %%
from matplotlib import font_manager, rc # 한글을 처리하기 위한 import

# %%
f_path = "C:/Windows/Fonts/malgunbd.ttf" # 글꼴 지정하기!
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc("font", family = font_name) # 한글 폰트 지정하기!

# %%
plt.rcParams["axes.unicode_minus"] = False # 깨지는 축 수정해 놓기

# %%
def call():
    return 100, 200 # 파이썬은 리턴을 그냥 여러개 찍어서 보낼 수 있다.(튜플로 리턴된다)
print(call())
# Out:
# (100, 200)

# %%
x, y = call() # 리턴값을 바로 변수에 순서대로 넣어줄 수 있다.
print(x, y)
# Out:
# 100 200

# %%
f, ax = plt.subplots(1, 2, figsize = (16, 8))
# 여러줄의 그래프를 만들때 사용하는 함수 subplots 1개의 행에 2개를 만들꺼다
# 사이즈 조절은 figsize로 가능
not_ex_sex["운동을 할 충분한 시간이 없어서"].plot.pie(explode=[0, 0.02], ax=ax[0], autopct="%1.1f%%")
not_ex_sex["함께 운동을 할 사람이 없어서"].plot.pie(explode=[0, 0.02], ax=ax[1], autopct="%1.1f%%")
ax[0].set_title("운동할 시간이 없음")
ax[1].set_title("운동할 사람이 없음")
plt.show()

# %%
# 왼쪽이 ax0, 오른쪽이 ax1이 된다.

# %%
not_excercise[not_excercise["대분류"] == "연령별"] # 조건을 안으로 주면 해당 조건값만 추출가능
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.7              6.1               5.6
# 4  연령별     20대               54.8              6.9               5.2
# 5  연령별     30대               58.1              5.5               4.6
# 6  연령별     40대               57.7              6.8               5.2
# 7  연령별     50대               50.1              9.2               7.2
# 8  연령별  60대 이상               27.5             12.8               6.9
#
#    운동을 싫어해서   기타
# 3      32.2  0.3
# 4      32.9  0.1
# 5      31.6  0.2
# 6      29.4    1
# 7      32.2  1.4
# 8      46.8    6

# %%
not_ex_age = not_excercise[not_excercise["대분류"] == "연령별"].copy() # 깊은 복사를 위한 copy()
not_ex_age
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.7              6.1               5.6
# 4  연령별     20대               54.8              6.9               5.2
# 5  연령별     30대               58.1              5.5               4.6
# 6  연령별     40대               57.7              6.8               5.2
# 7  연령별     50대               50.1              9.2               7.2
# 8  연령별  60대 이상               27.5             12.8               6.9
#
#    운동을 싫어해서   기타
# 3      32.2  0.3
# 4      32.9  0.1
# 5      31.6  0.2
# 6      29.4    1
# 7      32.2  1.4
# 8      46.8    6

# %%
not_ex_age.drop(columns="대분류", inplace=True) # 필요없는 대분류 drop
not_ex_age
# Out:
#        분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 3     10대               55.7              6.1               5.6      32.2  0.3
# 4     20대               54.8              6.9               5.2      32.9  0.1
# 5     30대               58.1              5.5               4.6      31.6  0.2
# 6     40대               57.7              6.8               5.2      29.4    1
# 7     50대               50.1              9.2               7.2      32.2  1.4
# 8  60대 이상               27.5             12.8               6.9      46.8    6

# %%
not_ex_age.set_index("분류", inplace=True) # 인덱스를 분류로 설정!
not_ex_age
# Out:
#         운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 분류
# 10대                  55.7              6.1               5.6      32.2  0.3
# 20대                  54.8              6.9               5.2      32.9  0.1
# 30대                  58.1              5.5               4.6      31.6  0.2
# 40대                  57.7              6.8               5.2      29.4    1
# 50대                  50.1              9.2               7.2      32.2  1.4
# 60대 이상               27.5             12.8               6.9      46.8    6

# %%
f2, ax2 = plt.subplots(2, 2, figsize = (16, 8)) # subplots를 사용해서 한번에 2개의 그래프를 그릴 수 있다.
# 사이즈도 조정 가능 subplots(줄갯수, 그래프 갯수, figsize = (전체 그래프 추출되는 영역의 크기))
not_ex_age["운동을 할 충분한 시간이 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[0][0], autopct="%1.1f%%")
not_ex_age["함께 운동을 할 사람이 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[0][1], autopct="%1.1f%%")
not_ex_age["운동을 할 만한 장소가 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[1][0], autopct="%1.1f%%")
not_ex_age["운동을 싫어해서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[1][1], autopct="%1.1f%%")
# explode는 각각의 영역의 간격? 
ax2[0][0].set_title("운동할 시간이 없음")
ax2[0][1].set_title("운동할 사람이 없음")
ax2[1][0].set_title("운동할 장소가 없음")
ax2[1][1].set_title("운동을 싫어함")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-f7faba3525be> in <module>()
#       1 f2, ax2 = plt.subplots(2, 2, figsize = (16, 8)) # subplots를 사용해서 한번에 2개의 그래프를 그릴 수 있다.
#       2 # 사이즈도 조정 가능 subplots(줄갯수, 그래프 갯수, figsize = (전체 그래프 추출되는 영역의 크기))
# ----> 3 not_ex_age["운동을 할 충분한 시간이 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[0], autopct="%1.1f%%")
#       4 not_ex_age["함께 운동을 할 사람이 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[1], autopct="%1.1f%%")
#       5 not_ex_age["운동을 할 만한 장소가 없어서"].plot.pie(explode=[0.02, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax2[2], autopct="%1.1f%%")
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwds)
#    2906         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2907         """
# -> 2908         return self(kind='pie', **kwds)
#    2909
#    2910
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     257         self._args_adjust()
#     258         self._compute_plot_data()
# --> 259         self._setup_subplots()
#     260         self._make_plot()
#     261         self._add_table()
#
# D:\anaconda\lib\site-packages\pandas\plotting\_core.py in _setup_subplots(self)
#     311                 axes = fig.add_subplot(111)
#     312             else:
# --> 313                 fig = self.ax.get_figure()
#     314                 if self.figsize is not None:
#     315                     fig.set_size_inches(self.figsize)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_figure'
